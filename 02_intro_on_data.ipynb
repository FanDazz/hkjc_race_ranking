# %% [markdown]
# # Details on Data

# %%
from pandas import read_csv

# perform for every race
perform = read_csv('./data/performance.txt', sep=':', encoding='utf-8')
# url 
horse = read_csv('./data/url_horse.txt', sep=':', encoding='utf-8')
jockey = read_csv('./data/url_jockey.txt', sep=':', encoding='utf-8')
trainer = read_csv('./data/url_trainer.txt', sep=':', encoding='utf-8')

# %% [markdown]
# ## 1 Performance
#
# Performance records the result of each race. Generally speaking, each competetion contains around 10 races, with around 10 jockeys riding on horses train.
#
# <img src="./pic/race.png" width="60%" height="60%">

# %% [markdown]
# - Race Date: 比赛日期
# - Race No.: 场次号
# - Race Course: 赛道
# - Distance: 赛程
# - Field Going: 场地情况
# - Race Name: 赛名
# - Course Type: 赛道类型
# - Race Money: 单场奖金
# - Pla.: 赛中名次
# - Horse No.: 赛中马号
# - Horse: 马名
# - Jockey: 骑士
# - Trainer: 练马师
# - Act. Wt.: 实际负磅
# - Declare. Horse Wt.: 排位体重
# - Dr.: 档位
# - LBW: 头马距离
# - Running Position: 沿途走位，i.e. 名词变化
# - Finish Time(min): 完成时间（分钟的部分）
# - Finish Time(sec): 完成时间（秒的部分）
# - Win Odds: 独赢赔率

# %%
perform.head(10)
# Out:
#     Race Date  Race No. Race Course              Distance Field Going  \
# 0  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 1  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 2  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 3  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 4  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 5  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 6  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 7  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 8  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
# 9  2022/12/18         1          ST  第五班 - 1400米 - (40-0)          好地
#
#        Race Name  Course Type   Race Money Pla. Horse No.  ... Jockey Trainer  \
# 0  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    1         2  ...     潘頓      賀賢
# 1  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    2         5  ...     布文     告東尼
# 2  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    3         3  ...    何澤堯     蘇偉賢
# 3  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    4         6  ...    蘇兆輝     黎昭昇
# 4  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    5         7  ...    希威森     苗禮德
# 5  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    6        14  ...    波健士     丁冠豪
# 6  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    7         1  ...    田泰安     文家良
# 7  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    8        11  ...    周俊樂     葉楚航
# 8  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000    9        13  ...    麥利奧     容天鵬
# 9  六福珠寶HEXICON讓賽  草地 - C+3 賽道  HK$ 810,000   10         8  ...    潘明輝     徐雨石
#
#   Act. Wt.  Declare. Horse Wt. Dr.    LBW Running Position Finish Time(min)  \
# 0      135                1200   8      -       10 11 11 1                1
# 1      129                1206  12  1-3/4       13 13 14 2                1
# 2      134                1230   6  2-1/2        9 10 10 3                1
# 3      127                1093  10      3       12 12 12 4                1
# 4      126                1225   3  3-1/4          2 3 3 5                1
# 5      115                1037   7  4-1/4          4 8 9 6                1
# 6      135                1119   2  4-1/4          7 5 4 7                1
# 7      121                1110   4  4-1/4          8 7 6 8                1
# 8      120                1081  11  5-3/4         11 9 8 9                1
# 9      124                1224   1  6-1/4         3 1 1 10                1
#
#   Finish Time(sec) Win Odds
# 0            22.80      2.6
# 1            23.06      8.5
# 2            23.20      7.4
# 3            23.26     42.0
# 4            23.33      6.0
# 5            23.48     21.0
# 6            23.48     21.0
# 7            23.48     39.0
# 8            23.73     47.0
# 9            23.79     38.0
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 2 Url
#
# Url can be used to further acquire more data on entities of interest.
#
# The table only contains 2 fields, entity and its url.

# %%
horse.head(), jockey.head(), trainer.head()
# Out:
# (        horse                                                url
#  0  喜悅精靈(E388)  /racing/information/Chinese/Horse/Horse.aspx?H...
#  1  勇敢動力(D153)  /racing/information/Chinese/Horse/Horse.aspx?H...
#  2  合夥贛勁(D051)  /racing/information/Chinese/Horse/Horse.aspx?H...
#  3    安寶(E407)  /racing/information/Chinese/Horse/Horse.aspx?H...
#  4   創高峰(D136)  /racing/information/Chinese/Horse/Horse.aspx?H...,
#    jockey                                                url
#  0     潘頓  /racing/information/Chinese/Jockey/JockeyProfi...
#  1     布文  /racing/information/Chinese/Jockey/JockeyProfi...
#  2    何澤堯  /racing/information/Chinese/Jockey/JockeyProfi...
#  3    蘇兆輝  /racing/information/Chinese/Jockey/JockeyProfi...
#  4    希威森  /racing/information/Chinese/Jockey/JockeyProfi...,
#    trainer                                                url
#  0      賀賢  /racing/information/Chinese/Trainers/TrainerPr...
#  1     告東尼  /racing/information/Chinese/Trainers/TrainerPr...
#  2     蘇偉賢  /racing/information/Chinese/Trainers/TrainerPr...
#  3     黎昭昇  /racing/information/Chinese/Trainers/TrainerPr...
#  4     苗禮德  /racing/information/Chinese/Trainers/TrainerPr...)
