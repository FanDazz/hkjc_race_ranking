# %% [markdown]
# # Details on Data

# %%
from pandas import read_csv

# perform for every race
perform = read_csv('./data/performance.txt', sep=':', encoding='utf-8')
# url 
horse = read_csv('./data/url_horse.txt', sep=':', encoding='utf-8')
jockey = read_csv('./data/url_jockey.txt', sep=':', encoding='utf-8')
trainer = read_csv('./data/url_trainer.txt', sep=':', encoding='utf-8')

# %% [markdown]
# ## 1 Performance
#
# Performance records the result of each race. Generally speaking, each competetion contains around 10 races, with around 10 jockeys riding on horses train

# %%
perform
# Out:
#         Race Date  Race No. Race Course               Distance Field Going  \
# 0      2022/12/18         1          ST   第五班 - 1400米 - (40-0)          好地
# 1      2022/12/18         1          ST   第五班 - 1400米 - (40-0)          好地
# 2      2022/12/18         1          ST   第五班 - 1400米 - (40-0)          好地
# 3      2022/12/18         1          ST   第五班 - 1400米 - (40-0)          好地
# 4      2022/12/18         1          ST   第五班 - 1400米 - (40-0)          好地
# ...           ...       ...         ...                    ...         ...
# 55527  2022/12/21         9          HV  第三班 - 1200米 - (80-60)       好地至快地
# 55528  2022/12/21         9          HV  第三班 - 1200米 - (80-60)       好地至快地
# 55529  2022/12/21         9          HV  第三班 - 1200米 - (80-60)       好地至快地
# 55530  2022/12/21         9          HV  第三班 - 1200米 - (80-60)       好地至快地
# 55531  2022/12/21         9          HV  第三班 - 1200米 - (80-60)       好地至快地
#
#            Race Name  Course Type     Race Money Pla. Horse No.  ... Jockey  \
# 0      六福珠寶HEXICON讓賽  草地 - C+3 賽道    HK$ 810,000    1         2  ...     潘頓
# 1      六福珠寶HEXICON讓賽  草地 - C+3 賽道    HK$ 810,000    2         5  ...     布文
# 2      六福珠寶HEXICON讓賽  草地 - C+3 賽道    HK$ 810,000    3         3  ...    何澤堯
# 3      六福珠寶HEXICON讓賽  草地 - C+3 賽道    HK$ 810,000    4         6  ...    蘇兆輝
# 4      六福珠寶HEXICON讓賽  草地 - C+3 賽道    HK$ 810,000    5         7  ...    希威森
# ...              ...          ...            ...  ...       ...  ...    ...
# 55527           土星讓賽    草地 - C 賽道  HK$ 1,725,000    8         2  ...    田泰安
# 55528           土星讓賽    草地 - C 賽道  HK$ 1,725,000    9         6  ...    賀銘年
# 55529           土星讓賽    草地 - C 賽道  HK$ 1,725,000   10         8  ...    楊明綸
# 55530           土星讓賽    草地 - C 賽道  HK$ 1,725,000   11         7  ...    潘明輝
# 55531           土星讓賽    草地 - C 賽道  HK$ 1,725,000   12         5  ...    希威森
#
#       Trainer Act. Wt.  Declare. Horse Wt. Dr.     LBW Running Position  \
# 0          賀賢      135                1200   8       -       10 11 11 1
# 1         告東尼      129                1206  12   1-3/4       13 13 14 2
# 2         蘇偉賢      134                1230   6   2-1/2        9 10 10 3
# 3         黎昭昇      127                1093  10       3       12 12 12 4
# 4         苗禮德      126                1225   3   3-1/4          2 3 3 5
# ...       ...      ...                 ...  ..     ...              ...
# 55527     告東尼      133                1216  11       6            1 1 8
# 55528     黎昭昇      122                1245  12       6          11 12 9
# 55529     丁冠豪      121                1137   6       7           2 2 10
# 55530     徐雨石      119                1112   1   8-1/4           7 7 11
# 55531     呂健威      123                1111   4  10-1/4           5 5 12
#
#       Finish Time(min) Finish Time(sec) Win Odds
# 0                    1            22.80      2.6
# 1                    1            23.06      8.5
# 2                    1            23.20      7.4
# 3                    1            23.26     42.0
# 4                    1            23.33      6.0
# ...                ...              ...      ...
# 55527                1            09.93      9.4
# 55528                1            09.94     43.0
# 55529                1            10.09     41.0
# 55530                1            10.28    218.0
# 55531                1            10.59     15.0
#
# [55532 rows x 21 columns]
